# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 8</b></center>
# <center><b><h3>Roll No : 24010101290</b></center>
# <center><b><h3>Name : VaishviVachhhani</b></center>
# <pre>

# %% [markdown]
# ### 01) WAP to find their union, intersection, and difference of the given two sets.
# **Sample Input:**
# ```
# A = {1, 2, 3, 4}
# B = {3, 4, 5, 6}
#
# ```
# **Sample Output:**
# ```
# Union: {1, 2, 3, 4, 5, 6}
# Intersection: {3, 4}
# Difference (A-B): {1, 2}
#
# ```

# %%
a = set(map(int,input("enter elements:").split()))
b = set(map(int,input("enter elements:").split()))
print("union:",a|b)
print("intersection:",a&b)
print("difference:",a-b)
# Out:
# enter elements: 1 2 3 4
# enter elements: 3 4 5 6
# union: {1, 2, 3, 4, 5, 6}
# intersection: {3, 4}
# difference: {1, 2}
# symmetric: {1, 2, 5, 6}

# %% [markdown]
# ### 02) WAP to Find elements common to all three given sets.
# **Sample Input:**
# ```
# A = {1, 2, 3, 4}
# B = {2, 3, 5}
# C = {2, 3, 6}
#
# ```
# **Sample Output:**
# ```
# {2, 3}
# ```

# %%
a = set(map(int,input("enter elements:").split()))
b = set(map(int,input("enter elements:").split()))
c = set(map(int,input("enter elements:").split()))
print(a&b&c)
# Out:
# enter elements: 1 2 3 4
# enter elements: 2 3 5
# enter elements: 2 3 6
# {2, 3}

# %% [markdown]
# ### 03) WAP to remove duplicate elements from a list while preserving unique values.
# **Sample Input:**
# ```
# [10, 20, 10, 30, 20, 40]
#
# ```
# **Sample Output:**
# ```
# {10, 20, 30, 40}
# ```

# %%
a = list(map(int,input("enter elements:").split()))
s = set()
for i in range (0,len(a)):
    if a[i] not in s:
        s.add(a[i])
print(s)
# Out:
# enter elements: 10 20 10 30 20 40
# {40, 10, 20, 30}

# %% [markdown]
# ### 04) WAP to count how many elements are common between two sets.
#
# **Sample Input:**
# ```
# A = {1, 2, 3, 4}
# B = {3, 4, 5, 6}
# ```
# **Sample Output:**
# ```
# 2
# ```

# %%
a = set(map(int,input("enter elements:").split()))
b = set(map(int,input("enter elements:").split()))
c = a&b
d = len(c)
print(d)
# Out:
# enter elements: 3 4 5 6
# enter elements: 1 2 3 4
# 2

# %% [markdown]
# ### 05) WAP to Merge two dictionaries. If a key exists in both dictionaries, add their values.
#
# **Sample Input:**
# ```
# Dict1 = {1: 10, 2: 20, 3: 30}
# Dict2 = {2: 40, 3: 50, 4: 60}
#
# ```
# **Sample Output:**
# ```
# {1: 10, 2: 60, 3: 80, 4: 60}
# ```

# %%
# d1 = {}
# d2 = {}
# n1 = int(input("enter number of elemnts in d1:"))
# for i in range (n1):
#     key = int(input("enter key:"))
#     value = int(input("enter value:"))
#     d1[key]=value
    
# n2 = int(input("enter number of elemnts in d2:"))
# for i in range (n2):
#     key = int(input("enter key:"))
#     value = int(input("enter value:"))
#     d2[key]=value

l1 = [(1,10),(2,20),(3,30)]
l2 = [(2,40),(3,50),(4,60)]
d1=dict(l1)
d2=dict(l2)

result = {}
for k in d1:
    result[k]=d1[k]

for k in d2:
    if k in result:
        result[k]=result[k]+d2[k]
    else:
        result[k]=d2[k]
print(result)
# Out:
# {1: 10, 2: 60, 3: 80, 4: 60}

# %% [markdown]
# ### 06) WAP to Sort a dictionary in ascending order of its values.
# Hint: in sorted(), use udf for key parameter
#
#
# **Sample Input:**
# ```
# {'Math': 70, 'Physics': 85, 'Chemistry': 60}
#
# ```
# **Sample Output:**
# ```
# {'Chemistry': 60, 'Math': 70, 'Physics': 85}
# ```

# %%
l1 = [('Maths',70),('Physics',85),('Chemistry',60)]
d1 = dict(l1)
def get_value(item):
    return item[1]

sorted_dict = dict(sorted(d1.items(),key=get_value))
print(sorted_dict)
# Out:
# {'Chemistry': 60, 'Maths': 70, 'Physics': 85}

# %% [markdown]
# ### 07) WAP to find the keys having maximum and minimum values in a dictionary.
#
# **Sample Input:**
# ```
# {'A': 50, 'B': 90, 'C': 30}
# ```
# **Sample Output:**
# ```
# Max Value Key: B
# Min Value Key: C
#
# ```

# %%
l1 = [('A',50),('B',90),('C',30)]
d1 = dict(l1)
max_key = max(d1,key=d1.get)
min_key = min(d1,key=d1.get)
print("max",max_key)
print("min",min_key)
# Out:
# max B
# min C

# %% [markdown]
# ### 08) WAP to create a dictionary with numbers from 1 to N as keys and their squares as values.
#
# **Sample Input:**
# ```
# N = 5
# ```
# **Sample Output:**
# ```
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
# ```

# %%
l = int(input("enter n:"))
res = [i**2 for i in range (1,l+1)]
d1 = dict(enumerate(res,start=1))
print(d1)
# Out:
# enter n: 5
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %% [markdown]
# ### 09) WAP to count the frequency of each character in a string using a dictionary.
# **Sample Input:**
# ```
# programming
# ```
# **Sample Output:**
# ```
# {'p': 1, 'r': 2, 'o': 1, 'g': 2, 'a': 1, 'm': 2, 'i': 1, 'n': 1}
# ```

# %%
l = input("enter string:")
freq = {}
for ch in l:
    if ch!='':
        freq[ch]=freq.get(ch,0)+1
print(freq)
# Out:
# enter string: programming
# {'p': 1, 'r': 2, 'o': 1, 'g': 2, 'a': 1, 'm': 2, 'i': 1, 'n': 1}

# %% [markdown]
# ### 10) WAP to swap keys and values of a dictionary.
# **Sample Input:**
# ```
# {1: 'A', 2: 'B', 3: 'C'}
# ```
# **Sample Output:**
# ```
# {'A': 1, 'B': 2, 'C': 3}
# ```

# %%
l = [(1,'A'),(2,'B'),(3,'C')]
d1 = dict(l)
d2 = {}
for k,v in d1.items():
    d2[v]=k
print(d2)
# Out:
# {'A': 1, 'B': 2, 'C': 3}

# %% [markdown]
# ### 11) WAP to find the student with the highest total marks, given student names and their marks.
#
# **Sample Input:**
# ```
# {'Amit': [70, 80, 90], 'Riya': [85, 75, 80], 'Neha': [60, 70, 65]}
# ```
# **Sample Output:**
# ```
# Topper: Amit
# ```

# %%
l1 = [('Amit',[70, 80, 90]),('Riya',[85, 75, 80]),('Neha',[60, 70, 65])]
d1 = dict(l1)
highest_total = 0
topper = ''
for stu,m in d1.items():
    total = sum(m)
    if total > highest_total:
        highest_total = total
        topper = stu
print(topper)
# Out:
# Amit

# %% [markdown]
# ### 12) WAP to extract keys whose values are even numbers.
#
# **Sample Input:**
# ```
# {1: 11, 2: 20, 3: 15, 4: 40}
# ```
# **Sample Output:**
# ```
# [2, 4]
# ```

# %%
l1 = [(1,11),(2,20),(3,15),(4,40)]
d1 = dict(l1)
res = [k for k,v in d1.items() if v%2==0]
print(res)
# Out:
# [2, 4]

# %% [markdown]
# ### 13) WAP to Find common keys between two dictionaries.
#
# **Sample Input:**
# ```
# Dict1 = {1: 'A', 2: 'B', 3: 'C'}
# Dict2 = {2: 'X', 3: 'Y', 4: 'Z'}
#
# ```
# **Sample Output:**
# ```
# [2, 3]
# ```

# %%
d1 = {1: 'A', 2: 'B', 3: 'C'}
d2 = {2: 'X', 3: 'Y', 4: 'Z'}
res = list(d1.keys() & d2.keys())
print(res)
# Out:
# [2, 3]

# %% [markdown]
# ### 14) WAP to handle missing keys in dictionaries.
#
# **Sample Input - 1:**
# ```
# dict1 = {'a': 5, 'c': 8, 'e': 2}
# key = 'c'
# ```
# **Sample Output - 1:**
# ```
# 8
# ```
#
# **Sample Input - 2:**
# ```
# dict1 = {'a': 5, 'c': 8, 'e': 2}
# key = 'd'
# ```
# **Sample Output - 2:**
# ```
# Key Not Found
# ```

# %%
d1 = {}
n1 = int(input("enter number of elemnts in d1:"))
for i in range (n1):
    key = (input("enter key:"))
    value = int(input("enter value:"))
    d1[key]=value
k = input("enter key to find:")
print(d1.get(k,"key not found"))
# Out:
# enter number of elemnts in d1: 3
# enter key: a
# enter value: 5
# enter key: c
# enter value: 8
# enter key: e
# enter value: 2
# enter key to find: c
# 8

# %% [markdown]
# ### 15) WAP to create a dictionary using dictionary comprehension from two lists containing student names and marks. Include only those students in the dictionary whose marks are greater than or equal to 75.
#
# **Sample Input:**
# ```
# students = ['Amit', 'Riya', 'Neha', 'Karan']
# marks = [78, 72, 85, 60]
# ```
# **Sample Output:**
# ```
# {'Amit': 78, 'Neha': 85}
# ```

# %%
students = ['Amit', 'Riya', 'Neha', 'Karan']
marks = [78, 72, 85, 60]
res = {k:v for k,v in zip(students,marks) if v >= 75}
print(res)
# Out:
# {'Amit': 78, 'Neha': 85}
