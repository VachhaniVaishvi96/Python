# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 12</b></center>
# <center><b><h3>Roll No :474 </b></center>
# <center><b><h3>Name :vaishvi </b></center>
# <pre>

# %% [markdown]
# # Exception Handling

# %% [markdown]
# ### 01) WAP to handle following exceptions:
# 1. ZeroDivisionError
# 2. ValueError
# 3. TypeError
# #### Note: handle them using separate except blocks and also using single except block too.

# %%
try:
    a=10
    b=int(input())
    c=a/b
    print(c)
except ZeroDivisionError as err:
    print(err)
except ValueError as err:
    print(err)
except TypeError as err:
    print(err)
# Out:
#  sd
# invalid literal for int() with base 10: 'sd'

# %%
try:
    a=10
    b=int(input())
    c=a/b
    print(c)
except (ZeroDivisionError,ValueError,TypeError) as err:
    print(err)
# Out:
#  l
# invalid literal for int() with base 10: 'l'

# %% [markdown]
# ### 02)  WAP to handle following exceptions:
# 1. IndexError
# 2. KeyError

# %%
try:
    numbers = [10, 20, 30, 40]
    print("List:", numbers)
    
    index = int(input("Enter index number: "))
    print("Element at index", index, "is", numbers[index])

except IndexError:
    print("Error: Index out of range! Please enter valid index.")
# Out:
# List: [10, 20, 30, 40]
# Enter index number:  5
# Error: Index out of range! Please enter valid index.

# %%
try:
    student = {
        "name": "Vaishvi",
        "age": 20,
        "course": "BCA"
    }
    
    print("Dictionary:", student)
    
    key = input("Enter key to access value: ")
    print("Value:", student[key])

except KeyError:
    print("Error: Key not found in dictionary!")
# Out:
# Dictionary: {'name': 'Vaishvi', 'age': 20, 'course': 'BCA'}
# Enter key to access value:  5
# Error: Key not found in dictionary!

# %% [markdown]
# ### 03) WAP to handle following exceptions:
# 1. FileNotFoundError
# 2. ModuleNotFoundError

# %%
try:
    file = open('neew.txt', "r")
    content = file.read()
    print(content)
    file.close()

except FileNotFoundError:
    print("Error: File not found! Please check the file name.")
# Out:
# Error: File not found! Please check the file name.

# %%
try:
    import mymodule
    print("Module imported successfully!")

except ModuleNotFoundError:
    print("Error: Module not found! Please install or check module name.")
# Out:
# Error: Module not found! Please install or check module name.

# %% [markdown]
# ### 04) WAP that handles all type of exceptions in a single except block in standard error message format.

# %%
try:

    num1 = int(input("Enter first number: "))
    num2 = int(input("Enter second number: "))
    
    result = num1 / num2
    print("Result:", result)

    # IndexError
    my_list = [10, 20, 30]
    print("element:", my_list[5])

    # KeyError
    my_dict = {"name": "Vaishvi", "age": 20}
    print("Course:", my_dict["course"])

    #  FileNotFoundError
    file = open("abc.txt", "r")
    print(file.read())
    file.close()

except Exception as e:
    print("Error occurred!")
    print("Error Type:", type(e).__name__)
    print("Error Message:", e)
# Out:
# Enter first number:  1
# Enter second number:  1
# Result: 1.0
# Error occurred!
# Error Type: IndexError
# Error Message: list index out of range

# %% [markdown]
# ### 05) WAP to demonstrate else  and finally block.

# %%
try:
    balance=5000
    debit=200
    if(balance > 5000 or balance < 0):
        raise ValueError("insufficient amt.")
except ValueError as err:
    print(err)
else:
    balance-=debit
    print(balance)
finally:
    print('transaction completed')
# Out:
# 4800
# transaction completed

# %% [markdown]
# ### 06) WAP to create an udf divide(a,b) that handles ZeroDivisionError.

# %%
def divide(a, b):
    try:
        return a / b
    except ZeroDivisionError:
        return "Error: Division by zero is not allowed."

print(divide(10, 0))
# Out:
# Error: Division by zero is not allowed.

# %% [markdown]
# ### 07) WAP to accept item prices and calculate total. Raise ValueError if price is negative, otherwise print the total bill amount.

# %%
try:
    n = int(input("Enter number of items: "))
    total = 0

    for i in range(n):
        price = float(input(f"Enter price of item {i+1}: "))
        
        if price < 0:
            raise ValueError("Price cannot be negative!")
        
        total += price

    print("Total Bill Amount:", total)

except ValueError as e:
    print("Error:", e)
# Out:
# Enter number of items:  5
# Enter price of item 1:  12
# Enter price of item 2:  -12
# Error: Price cannot be negative!

# %% [markdown]
# ### 08) Create a short program that prompts the user for a list of grades separated by commas.
# #### Split the string into individual grades and use a list comprehension to convert each string to an integer.
# #### You should use a try statement to inform the user when the values they entered cannot be converted.

# %%
try:
    grades_input = input("Enter grades separated by commas: ")
    grades = [int(grade.strip()) for grade in grades_input.split(",")]
    
    print("Grades List:", grades)
except ValueError:
    print("Error: Please enter only valid integer grades separated by commas.")
# Out:
# Enter grades separated by commas:  a,b,c,d
# Error: Please enter only valid integer grades separated by commas.

# %% [markdown]
# ### 09) Accept 5 subject marks (0-100). Use assert for validation.
#
# #### Sample Input (Error Case)
# #####  Enter marks: 110
#
# #### Sample Output (Error Case)
# ##### AssertionError: Marks should be between 0 and 100.
#
# #### Sample Input (Normal Case)
# ##### Valid marks entered
#
# #### Sample Output (Normal Case)
# ##### Average Marks displayed

# %%
try:
    marks = []
    
    for i in range(5):
        m = int(input(f"Enter marks for subject {i+1}: "))
        assert 0 <= m <= 100, "Marks should be between 0 and 100."
        marks.append(m)

    print("Valid marks entered")
    
    average = sum(marks) / 5
    print("Average Marks:", average)

except AssertionError as e:
    print("AssertionError:", e)
# Out:
# Enter marks for subject 1:  12
# Enter marks for subject 2:  52
# Enter marks for subject 3:  63
# Enter marks for subject 4:  96
# Enter marks for subject 5:  41
# Valid marks entered
# Average Marks: 52.8

# %% [markdown]
# ### 10) WAP that gets password from user. Password must have at least 8 characters and one digit.
# ### Raise WeakPasswordError if invalid, print the messsage "Correct" otherwise.

# %%
class WeakPasswordError(Exception):
    pass

try:
    password = input("Enter password: ")
    if len(password) < 8 or not any(char.isdigit() for char in password):
        raise WeakPasswordError("Password must have at least 8 characters and one digit.")
    print("Correct")

except WeakPasswordError as e:
    print("WeakPasswordError:", e)
# Out:
# Enter password:  errffvcefcefvrbef
# WeakPasswordError: Password must have at least 8 characters and one digit.

# %% [markdown]
# ### 11) WAP to raise your custom Exception named NegativeNumberError with the error message : "Cannot calculate the square root of a negative number" :
# #### if the given number is negative.
# #### otherwise print the square root of the given number.

# %%
import math
class NegativeNumberError(Exception):
    pass

try:
    num = float(input("Enter a number: "))
    
    if num < 0:
        raise NegativeNumberError("Cannot calculate the square root of a negative number")
    
    print("Square Root:", math.sqrt(num))

except NegativeNumberError as e:
    print("NegativeNumberError:", e)
# Out:
# Enter a number:  -26
# NegativeNumberError: Cannot calculate the square root of a negative number
